# %% [markdown]
# # Dr. X's Publications Analyzer - Jupyter Notebook

# %% [markdown]
# ## Import necessary libraries

# %%
import os
import time
import tempfile
import re
from typing import List, Dict, Tuple, Optional, Union, Any
import csv
import json
import logging
from pathlib import Path

# File handling
import docx
import PyPDF2
import pandas as pd
from io import BytesIO

# Vector DB
import chromadb
from chromadb.utils.embedding_functions import OllamaEmbeddingFunction

# NLP and embeddings
import nltk
from tiktoken import get_encoding
from sentence_transformers import CrossEncoder

# LLM interaction
import ollama
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document

# Evaluation 
from rouge import Rouge
import torch

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Initialize tokenizer
cl100k_tokenizer = get_encoding("cl100k_base")

# %% [markdown]
# ## Define system prompts

# %%
TRANSLATION_PROMPT = """
You are a professional translator. Translate the following text from {source_language} to {target_language}.
Maintain the original structure, formatting, and technical terminology as much as possible.
Here is the text to translate:

{text}
"""

SUMMARIZATION_PROMPT = """
You are an expert summarizer. Create a concise summary of the following text that captures the main ideas,
key findings and important details. The summary should be about {summary_length} of the original text.

Text to summarize:
{text}
"""

QA_PROMPT = """
You are an AI assistant tasked with providing detailed answers based solely on the given context. Your goal is to analyze the information provided and formulate a comprehensive, well-structured response to the question.

Context: {context}
Question: {question}
Previous Question (if any): {previous_question}
Previous Answer (if any): {previous_answer}

To answer the question:
1. Thoroughly analyze the context, identifying key information relevant to the question.
2. Take into account the previous question and answer if available to maintain conversation coherence.
3. Organize your thoughts and plan your response to ensure a logical flow of information.
4. Formulate a detailed answer that directly addresses the question, using only the information provided in the context.
5. If the context doesn't contain sufficient information to fully answer the question, state this clearly in your response.

Important: Base your entire response solely on the information provided in the context. Do not include any external knowledge or assumptions not present in the given text.
"""

# %% [markdown]
# ## Define the TokenCounter class

# %%
class TokenCounter:
    """Utility class to count tokens and measure processing speed."""
    
    def __init__(self):
        self.start_time = None
        self.end_time = None
        self.token_count = 0
        
    def start_counting(self):
        """Start the timer for performance measurement."""
        self.start_time = time.time()
        self.token_count = 0
        
    def add_tokens(self, text: str):
        """Count tokens in the provided text."""
        tokens = cl100k_tokenizer.encode(text)
        self.token_count += len(tokens)
        
    def end_counting(self) -> dict:
        """End timing and return performance metrics."""
        self.end_time = time.time()
        elapsed_time = self.end_time - self.start_time
        tokens_per_second = self.token_count / elapsed_time if elapsed_time > 0 else 0
        
        return {
            "elapsed_time_seconds": elapsed_time,
            "total_tokens": self.token_count,
            "tokens_per_second": tokens_per_second
        }

# %% [markdown]
# ## Define the TextExtractor class

# %%
class TextExtractor:
    """Extract text from various file formats."""
    
    @staticmethod
    def extract_from_docx(file_content: bytes) -> str:
        """Extract text from a .docx file."""
        doc = docx.Document(BytesIO(file_content))
        full_text = []
        
        # Extract text from paragraphs
        for para in doc.paragraphs:
            full_text.append(para.text)
            
        # Extract text from tables
        for table in doc.tables:
            for row in table.rows:
                row_text = []
                for cell in row.cells:
                    row_text.append(cell.text)
                full_text.append(" | ".join(row_text))
                
        return "\n".join(full_text)
    
    @staticmethod
    def extract_from_pdf(file_content: bytes) -> List[Dict[str, Union[str, int]]]:
        """Extract text from a PDF file with page numbers."""
        pdf_file = BytesIO(file_content)
        reader = PyPDF2.PdfReader(pdf_file)
        pages = []
        
        for i, page in enumerate(reader.pages):
            text = page.extract_text()
            pages.append({
                "page_number": i + 1,
                "content": text
            })
            
        return pages
    
    @staticmethod
    def extract_from_excel(file_content: bytes, file_extension: str) -> str:
        """Extract text from Excel files (.xlsx, .xls, .xlsm)."""
        df = pd.read_excel(BytesIO(file_content), sheet_name=None)
        full_text = []
        
        for sheet_name, sheet_df in df.items():
            full_text.append(f"Sheet: {sheet_name}")
            # Convert DataFrame to string representation
            full_text.append(sheet_df.to_string(index=True, header=True))
            
        return "\n\n".join(full_text)
    
    @staticmethod
    def extract_from_csv(file_content: bytes) -> str:
        """Extract text from CSV files."""
        csv_file = BytesIO(file_content)
        csv_reader = csv.reader(csv_file.read().decode('utf-8').splitlines())
        rows = list(csv_reader)
        
        # Format CSV data as text
        text_rows = []
        for row in rows:
            text_rows.append(" | ".join(row))
            
        return "\n".join(text_rows)
    
    @classmethod
    def extract_text(cls, file_path: str) -> Dict[str, Any]:
        """Extract text from a file based on its extension."""
        with open(file_path, 'rb') as file:
            file_content = file.read()
            
        file_extension = os.path.splitext(file_path)[1].lower()
        file_name = os.path.basename(file_path)
        
        if file_extension == '.docx':
            return {
                "text": cls.extract_from_docx(file_content),
                "pages": [{"page_number": 1, "content": cls.extract_from_docx(file_content)}],
                "source": file_name
            }
        elif file_extension == '.pdf':
            pages = cls.extract_from_pdf(file_content)
            return {
                "text": "\n".join([page["content"] for page in pages]),
                "pages": pages,
                "source": file_name
            }
        elif file_extension in ['.xlsx', '.xls', '.xlsm']:
            return {
                "text": cls.extract_from_excel(file_content, file_extension),
                "pages": [{"page_number": 1, "content": cls.extract_from_excel(file_content, file_extension)}],
                "source": file_name
            }
        elif file_extension == '.csv':
            return {
                "text": cls.extract_from_csv(file_content),
                "pages": [{"page_number": 1, "content": cls.extract_from_csv(file_content)}],
                "source": file_name
            }
        else:
            raise ValueError(f"Unsupported file extension: {file_extension}")

# %% [markdown]
# ## Define the TextChunker class

# %%
class TextChunker:
    """Break down texts into smaller, manageable parts."""
    
    def __init__(self, 
                 chunk_size: int = 400, 
                 chunk_overlap: int = 100,
                 separators: List[str] = ["\n\n", "\n", ".", "?", "!", " ", ""]):
        
        self.chunk_size = chunk_size
        self.chunk_overlap = chunk_overlap
        self.separators = separators
        self.text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=chunk_size,
            chunk_overlap=chunk_overlap,
            separators=separators
        )
        
    def chunk_document(self, document: Dict[str, Any]) -> List[Dict[str, Any]]:
        """
        Chunk a document into smaller parts using cl100k_base tokenizer.
        
        Args:
            document: Dictionary containing document text and metadata
            
        Returns:
            List of chunked documents with metadata
        """
        chunks = []
        chunk_counter = 0
        
        # Process each page
        for page in document["pages"]:
            page_number = page["page_number"]
            page_content = page["content"]
            
            # Create a Document object for the text splitter
            doc = Document(
                page_content=page_content,
                metadata={
                    "source": document["source"],
                    "page": page_number
                }
            )
            
            # Split the document
            split_docs = self.text_splitter.split_documents([doc])
            
            # Add chunk number to each split document
            for split_doc in split_docs:
                chunk_counter += 1
                split_doc.metadata["chunk"] = chunk_counter
                chunks.append({
                    "text": split_doc.page_content,
                    "metadata": split_doc.metadata
                })
                
        return chunks

# %% [markdown]
# ## Define the VectorDatabase class

# %%
class VectorDatabase:
    """Create and manage vector database for document chunks."""
    
    def __init__(self, db_path: str = "./vector_db", collection_name: str = "dr_x_publications"):
        self.db_path = db_path
        self.collection_name = collection_name
        
        # Create embedding function using Ollama
        self.embedding_function = OllamaEmbeddingFunction(
            url="http://localhost:11434/api/embeddings",
            model_name="nomic-embed-text:latest"
        )
        
        # Initialize ChromaDB client
        self.client = chromadb.PersistentClient(path=db_path)
        
        # Get or create collection
        self.collection = self.client.get_or_create_collection(
            name=collection_name,
            embedding_function=self.embedding_function,
            metadata={"hnsw:space": "cosine"}
        )
        
        self.token_counter = TokenCounter()
        
    def add_documents(self, chunks: List[Dict[str, Any]]) -> Dict[str, Any]:
        """
        Add document chunks to the vector database.
        
        Args:
            chunks: List of document chunks with text and metadata
            
        Returns:
            Dictionary containing performance metrics
        """
        documents, metadatas, ids = [], [], []
        
        self.token_counter.start_counting()
        
        for idx, chunk in enumerate(chunks):
            text = chunk["text"]
            metadata = chunk["metadata"]
            
            # Generate unique ID
            chunk_id = f"{metadata['source']}_{metadata['page']}_{metadata['chunk']}"
            
            documents.append(text)
            metadatas.append(metadata)
            ids.append(chunk_id)
            
            self.token_counter.add_tokens(text)
            
        # Add chunks to collection
        self.collection.upsert(
            documents=documents,
            metadatas=metadatas,
            ids=ids
        )
        
        return self.token_counter.end_counting()
    
    def query(self, query_text: str, n_results: int = 5) -> Tuple[List[str], List[Dict]]:
        """
        Query the vector database for relevant chunks.
        
        Args:
            query_text: The query text
            n_results: Number of results to return
            
        Returns:
            Tuple containing lists of documents and their metadata
        """
        self.token_counter.start_counting()
        self.token_counter.add_tokens(query_text)
        
        results = self.collection.query(
            query_texts=[query_text],
            n_results=n_results
        )
        
        performance = self.token_counter.end_counting()
        logger.info(f"Query performance: {performance}")
        
        return results["documents"][0], results["metadatas"][0]

# %% [markdown]
# ## Define the LanguageModel class

# %%
class LanguageModel:
    """Interface with local LLMs for various NLP tasks."""
    
    def __init__(self, model_name: str = "llama3.2:latest"):
        self.model_name = model_name
        self.token_counter = TokenCounter()
        self.previous_question = None
        self.previous_answer = None
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        
    def generate_answer(self, context: str, question: str) -> Tuple[str, Dict[str, Any]]:
        """
        Generate an answer to a question based on context.
        
        Args:
            context: The context for answering the question
            question: The question to answer
            
        Returns:
            Tuple containing the answer and performance metrics
        """
        self.token_counter.start_counting()
        
        # Add context and question to token count
        self.token_counter.add_tokens(context)
        self.token_counter.add_tokens(question)
        
        # Format prompt with previous Q&A if available
        prompt = QA_PROMPT.format(
            context=context,
            question=question,
            previous_question=self.previous_question if self.previous_question else "",
            previous_answer=self.previous_answer if self.previous_answer else ""
        )
        
        # Call Ollama
        response = ollama.generate(
            model=self.model_name,
            prompt=prompt
        )
        
        answer = response['response']
        
        # Update previous Q&A for context in next query
        self.previous_question = question
        self.previous_answer = answer
        
        # Count tokens in the response
        self.token_counter.add_tokens(answer)
        
        return answer, self.token_counter.end_counting()
    
    def translate_text(self, text: str, source_language: str, target_language: str) -> Tuple[str, Dict[str, Any]]:
        """
        Translate text between languages.
        
        Args:
            text: Text to translate
            source_language: Source language
            target_language: Target language
            
        Returns:
            Tuple containing translated text and performance metrics
        """
        self.token_counter.start_counting()
        
        prompt = TRANSLATION_PROMPT.format(
            source_language=source_language,
            target_language=target_language,
            text=text
        )
        
        self.token_counter.add_tokens(prompt)
        
        # Call Ollama
        response = ollama.generate(
            model=self.model_name,
            prompt=prompt
        )
        
        translation = response['response']
        self.token_counter.add_tokens(translation)
        
        return translation, self.token_counter.end_counting()
    
    def summarize_text(self, text: str, summary_ratio: float = 0.3) -> Tuple[str, Dict[str, Any]]:
        """
        Summarize text.
        
        Args:
            text: Text to summarize
            summary_ratio: Ratio of summary length to original text
            
        Returns:
            Tuple containing summary and performance metrics
        """
        self.token_counter.start_counting()
        
        prompt = SUMMARIZATION_PROMPT.format(
            text=text,
            summary_length=f"{int(summary_ratio * 100)}%"
        )
        
        self.token_counter.add_tokens(prompt)
        
        # Call Ollama
        response = ollama.generate(
            model=self.model_name,
            prompt=prompt
        )
        
        summary = response['response']
        self.token_counter.add_tokens(summary)
        
        return summary, self.token_counter.end_counting()
    
    def reset_conversation_context(self):
        """Reset the conversation context."""
        self.previous_question = None
        self.previous_answer = None

# %% [markdown]
# ## Define the DocumentAnalyzer class

# %%
class DocumentAnalyzer:
    """Main class for analyzing Dr. X's publications."""
    
    def __init__(self, 
                 vector_db_path: str = "./vector_db",
                 collection_name: str = "dr_x_publications",
                 llm_model: str = "llama3.2:latest"):
        
        self.text_extractor = TextExtractor()
        self.text_chunker = TextChunker()
        self.vector_db = VectorDatabase(vector_db_path, collection_name)
        self.language_model = LanguageModel(llm_model)
        self.rouge = Rouge()
        self.performance_metrics = []
        
    def process_document(self, file_path: str) -> Dict[str, Any]:
        """
        Process a document and add it to the vector database.
        
        Args:
            file_path: Path to the document
            
        Returns:
            Dictionary containing processing information
        """
        logger.info(f"Processing document: {file_path}")
        
        # Extract text from document
        document = self.text_extractor.extract_text(file_path)
        
        # Chunk the document
        chunks = self.text_chunker.chunk_document(document)
        
        # Add chunks to vector database
        performance = self.vector_db.add_documents(chunks)

        self.performance_metrics.append({
            "operation": "process_document",
            "file_path": file_path,
            **performance
        })
        
        return {
            "file_path": file_path,
            "chunks_created": len(chunks),
            "performance": performance
        }
    
    def process_directory(self, directory_path: str) -> List[Dict[str, Any]]:
        """
        Process all supported documents in a directory.
        
        Args:
            directory_path: Path to the directory
            
        Returns:
            List of processing information for each document
        """
        results = []
        
        # Get all files in directory
        file_paths = [os.path.join(directory_path, f) for f in os.listdir(directory_path) 
                     if os.path.isfile(os.path.join(directory_path, f))]
        
        # Filter to supported file types
        supported_extensions = ['.docx', '.pdf', '.csv', '.xlsx', '.xls', '.xlsm']
        file_paths = [f for f in file_paths if os.path.splitext(f)[1].lower() in supported_extensions]
        
        # Process each file
        for file_path in file_paths:
            try:
                result = self.process_document(file_path)
                results.append(result)
            except Exception as e:
                logger.error(f"Error processing {file_path}: {str(e)}")
                results.append({
                    "file_path": file_path,
                    "error": str(e)
                })
                
        return results
    
    def answer_question(self, question: str, n_results: int = 5) -> Dict[str, Any]:
        """
        Answer a question using the RAG system.
        
        Args:
            question: The question to answer
            n_results: Number of most relevant chunks to use
            
        Returns:
            Dictionary containing the answer and related information
        """
        # Query vector database
        documents, metadatas = self.vector_db.query(question, n_results)
        
        # Re-rank documents using cross-encoder if available
        try:
            relevant_documents, relevant_indices = self.rerank_documents(question, documents)
            relevant_metadata = [metadatas[i] for i in relevant_indices]
        except:
            logger.warning("Cross-encoder reranking failed, using original ranking")
            relevant_documents = documents
            relevant_metadata = metadatas
        
        # Join documents into context
        context = "\n\n".join(relevant_documents)
        
        # Generate answer
        answer, performance = self.language_model.generate_answer(context, question)
        # Store performance metrics
        self.performance_metrics.append({
            "operation": "answer_question",
            "question": question,
            **performance
        })
        
        return {
            "question": question,
            "answer": answer,
            "source_documents": relevant_documents,
            "source_metadata": relevant_metadata,
            "performance": performance
        }
    
    def rerank_documents(self, question: str, documents: List[str], top_k: int = 3) -> Tuple[List[str], List[int]]:
        """
        Re-rank documents using CrossEncoder for more accurate relevance.
        
        Args:
            question: The question
            documents: List of documents to rank
            top_k: Number of top documents to return
            
        Returns:
            Tuple containing list of re-ranked documents and their indices
        """
        if not documents:
            return [], []
            
        # Create pairs of (question, document) for each document
        pairs = [[question, doc] for doc in documents]
        
        # Load cross-encoder model
        cross_encoder = CrossEncoder('cross-encoder/ms-marco-MiniLM-L-6-v2', device=self.language_model.device)
        
        # Predict scores
        scores = cross_encoder.predict(pairs)
        
        # Get indices of top-k scoring documents
        top_indices = scores.argsort()[-top_k:][::-1]
        
        # Get top documents
        top_documents = [documents[i] for i in top_indices]
        
        return top_documents, top_indices.tolist()
    
    def translate_document(self, file_path: str, source_language: str, target_language: str) -> Dict[str, Any]:
        """
        Translate a document from one language to another.
        
        Args:
            file_path: Path to the document
            source_language: Source language
            target_language: Target language
            
        Returns:
            Dictionary containing the translated document and performance metrics
        """
        # Extract text from document
        document = self.text_extractor.extract_text(file_path)
        
        translated_pages = []
        total_performance = {"elapsed_time_seconds": 0, "total_tokens": 0, "tokens_per_second": 0}
        
        # Translate each page
        for page in document["pages"]:
            translated_text, performance = self.language_model.translate_text(
                page["content"], source_language, target_language
            )
            
            translated_pages.append({
                "page_number": page["page_number"],
                "content": translated_text
            })
            
            # Accumulate performance metrics
            total_performance["elapsed_time_seconds"] += performance["elapsed_time_seconds"]
            total_performance["total_tokens"] += performance["total_tokens"]
        
        # Calculate average tokens per second
        if total_performance["elapsed_time_seconds"] > 0:
            total_performance["tokens_per_second"] = (
                total_performance["total_tokens"] / total_performance["elapsed_time_seconds"]
            )
        # Store performance metrics
        self.performance_metrics.append({
            "operation": "translate_document",
            "file_path": file_path,
            **total_performance
        })
        
        return {
            "original_file": file_path,
            "source_language": source_language,
            "target_language": target_language,
            "translated_pages": translated_pages,
            "performance": total_performance
        }
    
    def summarize_document(self, file_path: str, summary_ratio: float = 0.3) -> Dict[str, Any]:
        """
        Summarize a document.
        
        Args:
            file_path: Path to the document
            summary_ratio: Ratio of summary length to original text
            
        Returns:
            Dictionary containing the summary and evaluation metrics
        """
        # Extract text from document
        document = self.text_extractor.extract_text(file_path)
        
        # Combine all pages
        full_text = "\n\n".join([page["content"] for page in document["pages"]])
        
        # Generate summary
        summary, performance = self.language_model.summarize_text(full_text, summary_ratio)
        
        # Evaluate using ROUGE
        rouge_scores = self.rouge.get_scores(summary, full_text)

        # Store performance metrics
        self.performance_metrics.append({
            "operation": "summarize_document",
            "file_path": file_path,
            **performance
        })
        return {
            "original_file": file_path,
            "summary": summary,
            "rouge_scores": rouge_scores[0],
            "performance": performance
        }
    
    def reset_conversation(self):
        """Reset the conversation context in the language model."""
        self.language_model.reset_conversation_context()

# %% [markdown]
# # Initialize the analyzer

# %%
analyzer = DocumentAnalyzer()
# Out:
# 2025-04-13 15:58:33,729 - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.

# %% [markdown]
# ## Process a single document

# %%
# Replace with your own file path
document_path = "Files/The_Plan_of_the_Giza_Pyramids.pdf"

# %%
result = analyzer.process_document(document_path)
print(f"Processed document: {document_path}")
print(f"Created {result['chunks_created']} chunks")
print(f"Performance: {result['performance']}")
# Out:
# 2025-04-13 15:58:40,675 - INFO - Processing document: Files/The_Plan_of_the_Giza_Pyramids.pdf
# 2025-04-13 15:58:42,976 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,046 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,104 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,157 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,209 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,261 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,291 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,311 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,329 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,350 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,370 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,389 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,410 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,428 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,448 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,467 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,486 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,503 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,522 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,543 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,562 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,582 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,599 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,617 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,634 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,654 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,672 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,690 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,708 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,725 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,743 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,761 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,779 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,798 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,816 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,834 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,854 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,873 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,892 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,912 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,931 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,954 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,976 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:43,995 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,015 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,034 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,055 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,073 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,092 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,111 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,129 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,148 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,167 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,186 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,207 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,225 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,245 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,264 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,283 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,304 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,322 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,342 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,361 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,381 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,400 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,420 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,440 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,460 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,481 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,500 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,520 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,540 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,559 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,579 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,599 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,618 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,637 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,657 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,676 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,695 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,715 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,734 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,753 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,774 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,793 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,813 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,834 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,854 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,874 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,894 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,915 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,935 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,955 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,975 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:44,996 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,016 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,037 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,057 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,077 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,097 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,118 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,138 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,158 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,183 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,205 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,227 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,248 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,268 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,288 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,309 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,329 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,348 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,370 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,392 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,412 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,433 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,454 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,475 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,495 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,516 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,536 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,556 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,577 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,598 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,618 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,640 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,660 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,681 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,702 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,723 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,746 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,766 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:58:45,787 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# Processed document: Files/The_Plan_of_the_Giza_Pyramids.pdf
# Created 133 chunks
# Performance: {'elapsed_time_seconds': 5.205222129821777, 'total_tokens': 11439, 'tokens_per_second': 2197.6007391622425}

# %% [markdown]
# ## Process multiple documents from a directory

# %%
# Replace with your own directory path
directory_path = "path/to/your/documents/"


results = analyzer.process_directory(directory_path)
print(f"Processed {len(results)} documents")
for result in results:
    if "error" in result:
        print(f"Error processing {result['file_path']}: {result['error']}")
    else:
        print(f"Processed {result['file_path']}: {result['chunks_created']} chunks")

# %% [markdown]
# ## Ask questions about the processed documents

# %%
question = "How does the document use Glen Dash’s surveys to validate or refine Petrie’s original measurements of the Giza pyramids?"


result = analyzer.answer_question(question, n_results=5)
print("\nQuestion:", result["question"])
print("\nAnswer:", result["answer"])
print("\nSource documents:")
for i, (doc, meta) in enumerate(zip(result["source_documents"], result["source_metadata"])):
    print(f"\n--- Document {i+1} ---")
    print(f"Source: {meta['source']}, Page: {meta['page']}, Chunk: {meta['chunk']}")
    print(doc[:150] + "..." if len(doc) > 150 else doc)
print("\nPerformance:", result["performance"])
# Out:
# 2025-04-13 15:59:00,423 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 15:59:00,450 - INFO - Query performance: {'elapsed_time_seconds': 2.1568589210510254, 'total_tokens': 25, 'tokens_per_second': 11.590929641247763}
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-04-13 15:59:05,595 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Question: How does the document use Glen Dash’s surveys to validate or refine Petrie’s original measurements of the Giza pyramids?
#
# Answer: Based on the provided context, it appears that Glen Dash's surveys conducted in 2012 and 2015, along with Ancient Egypt Research Associates, have validated or refined Petrie's original measurements of the Giza pyramids. The key information relevant to the question is:
#
# * Glen Dash's surveys were carried out in conjunction with Ancient Egypt Research Associates.
# * These surveys were done thirty years after Lehner and Goodman's work on the GPMP (Great Pyramid Mapping Project).
# * The surveys confirmed Petrie's original station marks at the corners of the Great Pyramid, which had previously been referenced to Petrie's stated coordinates.
#
# Based on this information, it can be inferred that Glen Dash's surveys provided confirmation or validation of Petrie's measurements. However, the context does not provide further details on how the surveys refined Petrie's measurements or any specific findings.
#
# Therefore, the answer to the question is:
#
# The document uses Glen Dash's surveys to validate Petrie's original measurements of the Giza pyramids by confirming his station marks and referencing his stated coordinates. The exact details of how the surveys refine Petrie's measurements are not specified in the context.
#
# Source documents:
#
# --- Document 1 ---
# Source: The_Plan_of_the_Giza_Pyramids.pdf, Page: 4, Chunk: 33
# to an error of scaling of about 1 part in 50, so that the grid coordinates of the Third Pyramid, for
# example,  are displaced  by about 18 metres.
# Co...
#
# --- Document 2 ---
# Source: tmpweipkz8w.pdf, Page: 4, Chunk: 33
# to an error of scaling of about 1 part in 50, so that the grid coordinates of the Third Pyramid, for
# example,  are displaced  by about 18 metres.
# Co...
#
# --- Document 3 ---
# Source: The_Plan_of_the_Giza_Pyramids.pdf, Page: 4, Chunk: 34
# and 2015 by the Glen Dash Foundation in conjunction with Ancient Egypt Research Associates,
# continuing the work of Lehner and Goodman for the GPMP so...
#
# Performance: {'elapsed_time_seconds': 3.3185977935791016, 'total_tokens': 491, 'tokens_per_second': 147.95405485714417}

# %% [markdown]
# # Translate a document

# %%
# Replace with your own file path
translate_file_path = "Files/The_Plan_of_the_Giza_Pyramids.pdf"
source_language = "English"
target_language = "Spanish"


result = analyzer.translate_document(translate_file_path, source_language, target_language)
print(f"\nTranslation from {source_language} to {target_language}:")
for page in result["translated_pages"]:
    print(f"\n--- Page {page['page_number']} ---")
    print(page["content"][:300] + "..." if len(page["content"]) > 300 else page["content"])
print("\nPerformance:", result["performance"])
# Out:
# 2025-04-13 15:59:20,882 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 15:59:27,475 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 15:59:39,698 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 15:59:53,904 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 16:00:08,148 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 16:00:21,490 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 16:00:29,386 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 16:00:35,380 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 16:00:43,054 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 16:00:49,057 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 16:01:01,024 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 16:01:07,290 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 16:01:12,570 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 16:01:20,301 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 16:01:33,592 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 16:01:49,798 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Translation from English to Spanish:
#
# --- Page 1 ---
# Here is the translation of the text from English to Spanish:
#
# El Plan de las Pirámides de Giza 1
#
# El Plan de las Pirámides de Giza
# por John A.R. Legon
# Fecha de revisión: 22-11-2019
#
# Mis hallazgos iniciales sobre el plan del sitio de las tres pirámides de Giza fueron brevemente resumidos en un foll...
#
# --- Page 2 ---
# Here is the translated text:
#
# El Plan de las Pirámides de Giza 2
#
# Se sugiere la existencia de un esquema dimensional subyacente a la colocación de las tres pirámides en primer lugar
# por la disposición muy regular de estas pirámides sobre el plano de Giza. Como resultado, los lados de los fundament...
#
# --- Page 3 ---
# Here is the translation of the text from English to Spanish:
#
# El Plan de las Pirámides de Giza 3
# Las dimensiones de los tres bases de pirámide, determinadas por Petrie, se presentan en la Tabla I, junto con las variaciones promedio en las longitudes de los lados y las orientaciones de las tres pirám...
#
# --- Page 4 ---
# Here is the translation of the text from English to Spanish:
#
# Plan de las pirámides de Giza (4)
# N lado 1er a S lado 3er Pirámide 35713.2 1731.97       1732
# S lado 1er a N lado 2do Pirámide 5159.7 250.23         250
# S lado 2do a N lado 3er Pirámide 8856.1 429.49 429.5
#
# Distancias desde el Este al Oes...
#
# --- Page 5 ---
# Here is the translation of the text from English to Spanish:
#
# El Plan de las Pirámides de Giza 5
#
# ha convertido las coordenadas de Petrie para los vértices y centros de las pirámides en coordenadas del grid GPMP,14 para obtener estimaciones lo más precisas posible de estas posiciones.
# Las coordena...
#
# --- Page 6 ---
# Aquí te presento la traducción del texto original en inglés al español:
#
# El Plan de las Pirámides de Giza 6
#
# Se construyó el plan. Las dimensiones se habrían medido desde el área noroeste del plateau, hacia el sur y oeste hasta la Segunda y Tercera Pirámide. La tarea de establecer el plan no sería ...
#
# --- Page 7 ---
# Here is the translation from English to Spanish:
#
# El Plan de las Pirámides de Giza 7
# La Gran Pirámide. Tomando una distancia adicional a lo largo del eje norte-sur, se respalda fuertemente la impresión de un diseño deliberado. La distancia hacia el sur desde la parte norte de la Gran Pirámide hasta...
#
# --- Page 8 ---
# Here is the translation of the provided text from English to Spanish:
#
# El Plan de las Pirámides de Giza   8
#
# Cubo. La longitud lateral del Segundo Pireo está definida como (1½ × 440 - 250) o 410 cubos,
# mientras que la separación este-oeste desde la Gran Pirámide se encuentra en (625 - 410) o 215 c...
#
# --- Page 9 ---
# Here is the translation of the text from English to Spanish:
#
# El Plan de las Pirámides de Giza 9
#
# De manera sorprendentemente razonable, estas dimensiones representan las raíces cuadradas de los primeros dos números primos, dos y tres, multiplicados por un factor de 1000. Los valores teóricos son:
# ...
#
# --- Page 10 ---
# Here is the translation of the text from English to Spanish:
#
#
# El Plan de las Pirámides de Giza 10
#
# divide la base en la proporción de √2 : √3. Consecuentemente, el largo marcado a lo largo del diágnamo 1: 1
# resulta ser:
#                        √2
# 1000 √3  ×   --------    ×  √2  =  1101.020…varas
# ...
#
# --- Page 11 ---
# Here is the translation from English to Spanish:
#
# El Plan de las Pirámides de Giza 11
#
# Es innecesario decir que estas construcciones geométricas son conceptuales y habrían sido trabajadas por el arquitecto a una escala conveniente en una mesa de dibujo o alfombra escritora.
# Solo las bases de las ...
#
# --- Page 12 ---
# Here is the translation of the text from English to Spanish:
#
# El Plan de las Pirámides de Giza  12
#
# Este es la longitud del diálogo en el rectángulo que mide 250 × 250 √2 cubitos, que se encuentra dentro del plan
# del sitio de Giza entre la dimensión norte-sur de 250 cubitos y la dimensión este-oes...
#
# --- Page 13 ---
# The translated text is:
#
# La planificación de las pirámides de Giza 13
#
# El dimensión es un producto natural de la geometría ya descrita, y puede construirse como el diálogo en una recta cuadrada que mide 250√2 por 250√5 cubiertos, o como el diálogo en una recta cuadrada que mide 250√3 por 500 cubier...
#
# --- Page 14 ---
# Here is the translated text from English to Spanish:
#
# El Plano de las Pirámides de Giza 14
#
# Restando la parte corta de la parte larga, se obtiene un resto de (631 - 353,5) o 277,5 cubitos,
# que está en la proporción de π:4 con respecto a la parte corta de 353,5 cubitos y se obtiene así la pendiente ...
#
# --- Page 15 ---
# Aquí está el texto traducido al español:
#
# El Plano de las Pirámides de Gizeh, Número 15
#
# También debemos destacar que la base del tercer pirámide es igual a la longitud de una caja, el volumen de
# la cual es equivalente al de una esfera con un diámetro igual al módulo de 250 cubitos. El lado exacto n...
#
# --- Page 16 ---
# Here is the translation of the text from English to Spanish:
#
#
# El Plan de las Pirámides de Giza  16
#
# Si, como cree el presente autor, la existencia del plan del sitio no puede ser reconciliada con la teoría funeraria, entonces no es la evidencia factual sólida de las relaciones dimensionales lo que...
#
# Performance: {'elapsed_time_seconds': 160.53347396850586, 'total_tokens': 21854, 'tokens_per_second': 136.13360167043672}

# %% [markdown]
# ## Summarize a document

# %%
# Replace with your own file path
summarize_file_path = "Files/The_Plan_of_the_Giza_Pyramids.pdf"
summary_ratio = 0.3  # 30% of original length


result = analyzer.summarize_document(summarize_file_path, summary_ratio)
print("\nSummary:")
print(result["summary"])
print("\nROUGE Scores:")
print(json.dumps(result["rouge_scores"], indent=2))
print("\nPerformance:", result["performance"])
# Out:
# 2025-04-13 16:02:53,244 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Summary:
# This is a long text that appears to be an academic article or a book excerpt on the topic of the Giza Pyramids and their construction. Here's a summary of the main points:
#
# **Introduction**
#
# The author argues that the traditional view of the Giza Pyramids, which attributes their construction to the Fourth Dynasty of Ancient Egypt, is unlikely and that there is evidence to suggest that they may be much older.
#
# **The Dimensions of the Pyramid**
#
# The author notes that the dimensions of the Great Pyramid are a key piece of evidence in support of the alternative theory. The pyramid's base is a square with sides of 230 meters, each side being divided into nine triangles, each triangle having an angle of 36 degrees. This corresponds to the golden ratio (φ) or phi, which is approximately 1.618. The author argues that this is no coincidence and that the use of φ in the pyramid's design suggests a deliberate attempt to express square roots.
#
# **The Use of Square Roots**
#
# Throughout the text, the author emphasizes the importance of square roots in the construction of the pyramids. They note that φ is approximately equal to 1 + √2/2, which means that it is related to the square root of 2. The author argues that this suggests a deep understanding of mathematics and geometry on the part of the builders.
#
# **The Turin King List and the Zep Tepi Era**
#
# The author cites the Turin King List, an ancient Egyptian document that lists the kings of Egypt, as evidence that the Giza Pyramids may predate the Fourth Dynasty. The list includes a reference to an era known as Zep Tepi (First Time), which is believed by some to refer to a remote antiquity period before the First Dynasty.
#
# **The Great Sphinx**
#
# The author notes that the Great Sphinx, a limestone statue with the body of a lion and the head of a human, is another monument that dates back to this era. The author argues that the Sphinx's position in the Giza plan suggests that it may have been built at the same time as the pyramids.
#
# **Conclusion**
#
# The author concludes by suggesting that the traditional view of the Giza Pyramids may be based on incomplete or inaccurate information, and that there is evidence to suggest that they may be much older than previously thought. The use of square roots, the dimensions of the pyramid, and the reference to Zep Tepi all support this theory.
#
# Overall, the text presents a complex and intriguing argument that challenges conventional wisdom about the construction of the Giza Pyramids.
#
# ROUGE Scores:
# {
#   "rouge-1": {
#     "r": 0.06611570247933884,
#     "p": 0.5628140703517588,
#     "f": 0.11833069014178242
#   },
#   "rouge-2": {
#     "r": 0.020145233075661746,
#     "p": 0.25,
#     "f": 0.037285929684165324
#   },
#   "rouge-l": {
#     "r": 0.05489964580873672,
#     "p": 0.46733668341708545,
#     "f": 0.0982567334592679
#   }
# }
#
# Performance: {'elapsed_time_seconds': 8.193687677383423, 'total_tokens': 10144, 'tokens_per_second': 1238.0261976545573}

# %% [markdown]
# ## Reset conversation context

# %%
analyzer.reset_conversation()
print("Conversation context reset")

# %% [markdown]
# ## Display performance metrics

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ensure plots render in Jupyter Notebook
# %matplotlib inline

# Check if performance_metrics exists and has data
if hasattr(analyzer, "performance_metrics") and analyzer.performance_metrics:
    print("\nPerformance Metrics:")
    try:
        metrics_df = pd.DataFrame(analyzer.performance_metrics)
        display(metrics_df)
        
        # Plot tokens per second over time if available
        if "tokens_per_second" in metrics_df.columns:
            plt.figure(figsize=(10, 6))
            plt.plot(metrics_df["tokens_per_second"], marker='o', linestyle='-', color='b')
            plt.title("Tokens Per Second Over Operations")
            plt.xlabel("Operation Index")
            plt.ylabel("Tokens/Second")
            plt.grid(True)
            plt.show()
        else:
            print("No 'tokens_per_second' data available for plotting.")
    except Exception as e:
        print(f"Error displaying metrics: {str(e)}")
else:
    print("\nNo performance metrics available. Process some documents or perform operations to generate metrics.")
# Out:
# 2025-04-13 16:04:35,568 - INFO - generated new fontManager
# Performance Metrics:
#             operation                                file_path  \
# 0    process_document  Files/The_Plan_of_the_Giza_Pyramids.pdf
# 1     answer_question                                      NaN
# 2  translate_document  Files/The_Plan_of_the_Giza_Pyramids.pdf
# 3  summarize_document  Files/The_Plan_of_the_Giza_Pyramids.pdf
#
#    elapsed_time_seconds  total_tokens  tokens_per_second  \
# 0              5.205222         11439        2197.600739
# 1              3.318598           491         147.954055
# 2            160.533474         21854         136.133602
# 3              8.193688         10144        1238.026198
#
#                                             question
# 0                                                NaN
# 1  How does the document use Glen Dash’s surveys ...
# 2                                                NaN
# 3                                                NaN

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\rag_q-a\venv\lib\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\rag_q-a\venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\rag_q-a\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\rag_q-a\venv\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\rag_q-a\venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\rag_q-a\venv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\rag_q-a\venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\rag_q-a\venv\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\rag_q-a\venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\rag_q-a\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\rag_q-a\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Analysis using different model for translation and summary

# %%
class LanguageModel:
    """Interface with local LLMs for various NLP tasks."""
    
    def __init__(self, model_name: str = "lauchacarro/qwen2.5-translator:latest"):
        self.model_name = model_name
        self.token_counter = TokenCounter()
        self.previous_question = None
        self.previous_answer = None
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        
  
    
    def translate_text(self, text: str, source_language: str, target_language: str) -> Tuple[str, Dict[str, Any]]:
        """
        Translate text between languages.
        
        Args:
            text: Text to translate
            source_language: Source language
            target_language: Target language
            
        Returns:
            Tuple containing translated text and performance metrics
        """
        self.token_counter.start_counting()
        
        prompt = TRANSLATION_PROMPT.format(
            source_language=source_language,
            target_language=target_language,
            text=text
        )
        
        self.token_counter.add_tokens(prompt)
        
        # Call Ollama
        response = ollama.generate(
            model=self.model_name,
            prompt=prompt
        )
        
        translation = response['response']
        self.token_counter.add_tokens(translation)
        
        return translation, self.token_counter.end_counting()
    
    def summarize_text(self, text: str, summary_ratio: float = 0.3) -> Tuple[str, Dict[str, Any]]:
        """
        Summarize text.
        
        Args:
            text: Text to summarize
            summary_ratio: Ratio of summary length to original text
            
        Returns:
            Tuple containing summary and performance metrics
        """
        self.token_counter.start_counting()
        
        prompt = SUMMARIZATION_PROMPT.format(
            text=text,
            summary_length=f"{int(summary_ratio * 100)}%"
        )
        
        self.token_counter.add_tokens(prompt)
        
        # Call Ollama
        response = ollama.generate(
            model=self.model_name,
            prompt=prompt
        )
        
        summary = response['response']
        self.token_counter.add_tokens(summary)
        
        return summary, self.token_counter.end_counting()
    
    def reset_conversation_context(self):
        """Reset the conversation context."""
        self.previous_question = None
        self.previous_answer = None

# %%
class DocumentAnalyzer:
    """Main class for analyzing Dr. X's publications."""
    
    def __init__(self, 
                 vector_db_path: str = "./vector_db",
                 collection_name: str = "dr_x_publications",
                 llm_model: str = "lauchacarro/qwen2.5-translator:latest"):
        
        self.text_extractor = TextExtractor()
        self.text_chunker = TextChunker()
        self.vector_db = VectorDatabase(vector_db_path, collection_name)
        self.language_model = LanguageModel(llm_model)
        self.rouge = Rouge()
        self.performance_metrics = []
        
    def process_document(self, file_path: str) -> Dict[str, Any]:
        """
        Process a document and add it to the vector database.
        
        Args:
            file_path: Path to the document
            
        Returns:
            Dictionary containing processing information
        """
        logger.info(f"Processing document: {file_path}")
        
        # Extract text from document
        document = self.text_extractor.extract_text(file_path)
        
        # Chunk the document
        chunks = self.text_chunker.chunk_document(document)
        
        # Add chunks to vector database
        performance = self.vector_db.add_documents(chunks)

        self.performance_metrics.append({
            "operation": "process_document",
            "file_path": file_path,
            **performance
        })
        
        return {
            "file_path": file_path,
            "chunks_created": len(chunks),
            "performance": performance
        }
    
    def process_directory(self, directory_path: str) -> List[Dict[str, Any]]:
        """
        Process all supported documents in a directory.
        
        Args:
            directory_path: Path to the directory
            
        Returns:
            List of processing information for each document
        """
        results = []
        
        # Get all files in directory
        file_paths = [os.path.join(directory_path, f) for f in os.listdir(directory_path) 
                     if os.path.isfile(os.path.join(directory_path, f))]
        
        # Filter to supported file types
        supported_extensions = ['.docx', '.pdf', '.csv', '.xlsx', '.xls', '.xlsm']
        file_paths = [f for f in file_paths if os.path.splitext(f)[1].lower() in supported_extensions]
        
        # Process each file
        for file_path in file_paths:
            try:
                result = self.process_document(file_path)
                results.append(result)
            except Exception as e:
                logger.error(f"Error processing {file_path}: {str(e)}")
                results.append({
                    "file_path": file_path,
                    "error": str(e)
                })
                
        return results
    

    
    def translate_document(self, file_path: str, source_language: str, target_language: str) -> Dict[str, Any]:
        """
        Translate a document from one language to another.
        
        Args:
            file_path: Path to the document
            source_language: Source language
            target_language: Target language
            
        Returns:
            Dictionary containing the translated document and performance metrics
        """
        # Extract text from document
        document = self.text_extractor.extract_text(file_path)
        
        translated_pages = []
        total_performance = {"elapsed_time_seconds": 0, "total_tokens": 0, "tokens_per_second": 0}
        
        # Translate each page
        for page in document["pages"]:
            translated_text, performance = self.language_model.translate_text(
                page["content"], source_language, target_language
            )
            
            translated_pages.append({
                "page_number": page["page_number"],
                "content": translated_text
            })
            
            # Accumulate performance metrics
            total_performance["elapsed_time_seconds"] += performance["elapsed_time_seconds"]
            total_performance["total_tokens"] += performance["total_tokens"]
        
        # Calculate average tokens per second
        if total_performance["elapsed_time_seconds"] > 0:
            total_performance["tokens_per_second"] = (
                total_performance["total_tokens"] / total_performance["elapsed_time_seconds"]
            )
        # Store performance metrics
        self.performance_metrics.append({
            "operation": "translate_document",
            "file_path": file_path,
            **total_performance
        })
        
        return {
            "original_file": file_path,
            "source_language": source_language,
            "target_language": target_language,
            "translated_pages": translated_pages,
            "performance": total_performance
        }
    
    def summarize_document(self, file_path: str, summary_ratio: float = 0.3) -> Dict[str, Any]:
        """
        Summarize a document.
        
        Args:
            file_path: Path to the document
            summary_ratio: Ratio of summary length to original text
            
        Returns:
            Dictionary containing the summary and evaluation metrics
        """
        # Extract text from document
        document = self.text_extractor.extract_text(file_path)
        
        # Combine all pages
        full_text = "\n\n".join([page["content"] for page in document["pages"]])
        
        # Generate summary
        summary, performance = self.language_model.summarize_text(full_text, summary_ratio)
        
        # Evaluate using ROUGE
        rouge_scores = self.rouge.get_scores(summary, full_text)

        # Store performance metrics
        self.performance_metrics.append({
            "operation": "summarize_document",
            "file_path": file_path,
            **performance
        })
        return {
            "original_file": file_path,
            "summary": summary,
            "rouge_scores": rouge_scores[0],
            "performance": performance
        }

# %%
analyzer = DocumentAnalyzer()
# Out:
# 2025-04-13 17:29:20,153 - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.

# %%
# Replace with your own file path
document_path = "Files/The_Plan_of_the_Giza_Pyramids.pdf"

# %%
result = analyzer.process_document(document_path)
print(f"Processed document: {document_path}")
print(f"Created {result['chunks_created']} chunks")
print(f"Performance: {result['performance']}")
# Out:
# 2025-04-13 17:29:25,487 - INFO - Processing document: Files/The_Plan_of_the_Giza_Pyramids.pdf
# 2025-04-13 17:29:28,409 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,433 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,454 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,475 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,496 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,519 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,542 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,562 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,586 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,605 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,627 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,646 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,668 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,688 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,707 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,726 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,747 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,767 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,789 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,811 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,829 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,851 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,871 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,895 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,917 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,938 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,959 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:28,981 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,003 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,022 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,040 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,061 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,080 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,101 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,122 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,144 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,163 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,184 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,203 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,223 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,245 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,270 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,293 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,315 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,337 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,358 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,379 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,399 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,418 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,436 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,458 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,480 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,500 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,521 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,546 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,568 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,588 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,607 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,625 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,648 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,669 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,689 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,711 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,732 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,755 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,775 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,795 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,815 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,834 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,854 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,875 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,897 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,918 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,938 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,958 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:29,979 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,002 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,024 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,044 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,064 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,087 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,108 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,130 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,154 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,174 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,195 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,219 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,238 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,261 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,281 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,301 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,321 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,342 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,362 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,382 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,404 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,424 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,445 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,468 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,491 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,512 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,533 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,556 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,578 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,599 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,621 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,641 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,664 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,687 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,708 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,732 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,755 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,777 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,798 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,822 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,843 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,863 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,883 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,905 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,926 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,951 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,974 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:30,996 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:31,016 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:31,038 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:31,059 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:31,082 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:31,103 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:31,124 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:31,151 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:31,179 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:31,205 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-04-13 17:29:31,230 - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# Processed document: Files/The_Plan_of_the_Giza_Pyramids.pdf
# Created 133 chunks
# Performance: {'elapsed_time_seconds': 5.790467023849487, 'total_tokens': 11439, 'tokens_per_second': 1975.4883246697748}

# %%
# Replace with your own file path
translate_file_path = "Files/The_Plan_of_the_Giza_Pyramids.pdf"
source_language = "English"
target_language = "German"


result = analyzer.translate_document(translate_file_path, source_language, target_language)
print(f"\nTranslation from {source_language} to {target_language}:")
for page in result["translated_pages"]:
    print(f"\n--- Page {page['page_number']} ---")
    print(page["content"][:300] + "..." if len(page["content"]) > 300 else page["content"])
print("\nPerformance:", result["performance"])
# Out:
# 2025-04-13 17:29:42,598 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 17:29:47,244 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 17:29:56,927 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 17:30:06,963 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 17:30:19,574 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 17:30:29,505 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 17:30:35,913 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 17:30:40,576 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 17:30:47,412 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 17:30:52,020 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 17:31:01,977 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 17:31:07,042 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 17:31:11,018 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 17:31:16,953 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 17:31:27,991 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# 2025-04-13 17:31:39,017 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Translation from English to German:
#
# --- Page 1 ---
# Das Entwurf der Pyramiden von Giza 1
#
# Das Entwurf der Pyramiden von Giza
# von John A.R. Legon
# Revision Datum:   22-11-2019
# Meine ersten Ergebnisse auf dem Giza-Situationsskizzen von drei Pyramiden wurden erst in einem kurzen Bericht veröffentlicht, das vom Archäologischen Verein Staten Island im ...
#
# --- Page 2 ---
# Das Geheimschema der Pläne der Giza-Pyramiden 2
#
# Die Existenz eines Dimensionsschemas unterstellt die Verteilung der drei Pyramiden auf dem Giza-Plateau. Aus diesem Grund definieren die Seiten des Basenrahmens und die Entfernungen, die sie trennen, konsekutive Axialentfernungen von Nord nach Süden ...
#
# --- Page 3 ---
# Die Planung der Giza-Pyramiden 3
# Die Dimensionen der drei Grundpyramidebasen wie von Petrie festgelegt sind in Tabelle I zusammen mit den durchschnittlichen Veränderungen an den Längen der Seiten und den Orientierungen der drei Pyramiden bezüglich des Nordsinnes. Die Entfernungen zwischen den Zentre...
#
# --- Page 4 ---
# Der Plan der Giza-Pyramiden 4
# N-Schritt von 1st zum 3rd Pyramid 35713.2 1731.97       1732
# S-Schritt von 1st zum 2nd Pyramid 5159.7 250.23         250
# S-Schritt von 2nd zum 3rd Pyramid 8856.1 429.49 429.5
# Abstände vom Ost zum Westen ...
# W-Schritt von 1st zum 2nd Pyramid 12868.8 624.09     ...
#
# --- Page 5 ---
# The Plan of the Giza Pyramids 5 has converted Petrie's coordinates for the corners and centres of the pyramids into coordinates in the GPMP grid,14 to give the best possible estimates for these positions. Petrie’s coordinates for the corners of the Second and Third Pyramids, as transformed by Glen D...
#
# --- Page 6 ---
# Das Entwurf der Giza-Pyramiden 6
# konstruiert. Die Dimensionen würden somit aus dem nördlichen-Nordwestlichen Bereich des Plateaus, südlich und westlich fortgesetzt werden, nach den Zweiten und Dritten Pyramiden hin. Das Aufstellen der Planung wäre daher in Prinzip nicht mehr schwieriger gewesen als...
#
# --- Page 7 ---
# Die Planung der Giza-Pyramiden 7
# der großen Pyramide. Nach weiteren Entfernungen entlang der Nord-Südachse wird die Eindruck einer
# planmäßigen Gestaltung stark unterstützt. Die Entfernung südwärts vom Norden des großen Pyramides zum Süden des zweiten Pyramides beträgt 1101 Kubikzoll, oder nur 0.1...
#
# --- Page 8 ---
# Die Planung der Giza-Pyramiden 8
# cubits. Der Flächeninhalt des zweiten Pyramiden ist definiert als (1½ × 440 - 250) oder 410 cubits, während die süd-nordliche Abstandsdifferenz vom größten Pyramiden festgestellt wird durch (625 - 410) oder 215 cubits:
# Unter Berücksichtigung dieser Modulansatzmodel...
#
# --- Page 9 ---
# Die Planung der Giza-Pyramiden 9
# Zwar überraschend, diese Dimensionen entsprechen den Quadratwurzeln zweier ersten Primzahlen, zwei und drei, multipliziert mit einem Faktor von 1000. Die theoretischen Werte sind:
#
#                    1000 √2 = 1414.21... ,      1000 √3 = 1732.05...
#
# Während die No...
#
# --- Page 10 ---
# Die Planung der Giza-Pyramiden 10
# teilen die Grundlinie in dem Verhältnis von √2 : √3. Folglich wird die Länge, die nach der Diagonalen des 1:1-Verhältnisses abgebildet ist, wie folgt berechnet:
#                        √2
# 1000 √3 × --------    × √2 = 1101.020…cubits
#                    √2 + √3
# Da...
#
# --- Page 11 ---
# Die Planung der Giza-Pyramiden 11
# Unbedingt zu betonen ist, dass diese geometrischen Konstruktionen konzeptionell sind und hätten von dem Architekten auf einer geeigneten Skala in Form eines Zeichnungsfeldes oder Schilderflächen ausgeführt werden können. Nur die Grundrisslinien der Pyramiden und d...
#
# --- Page 12 ---
# The Plan of the Giza Pyramids 12
# Dies ist die Länge der Diagonale im Quadrat mit dem Maßstab von 250 × 250√2 Kubikzentimeter, das in der Giza-Plattform zwischen den Nord-Süd-Dimensionen von 250 Kubikzentimetern und der Ost-West-Dimension von 353.5 Kubikzentimetern enthalten ist. Es ist jetzt klar,...
#
# --- Page 13 ---
# Das Geplanschte der Giza-Pyramiden 13
# ist eine natürliche Produkt des Geometries, die bereits beschrieben wurde., und kann als Diagonale in einem Rechteck mit Maß von 250 √2 × 250 √5 Kubikmitten konstruiert werden, oder als Diagonale in einem Rechteck mit Maß von 250 √3 × 500 Kubikmitten. In der Abs...
#
# --- Page 14 ---
# Das Giza-Plan 14
#
# Subtrahiert man die kurze Seite vom langen Seitenwert, ergibt sich eine Restgröße von (631 – 353.5) oder 277.5 Kubikmeter, was in der Proportion π:4 zu der kurzen Seite von 353.5 Kubikmitten entspricht und somit die π/4-Flachheitssteigung liefert:
#
# Wie im Diagramm gezeigt ist die...
#
# --- Page 15 ---
# Die Pläne der Pyramiden von Giza 15
#
# Wir müssen auch betonen, dass die Grundfläche des dritten Pyramiden gleich dem Quadrat eines Körpers ist, dessen Volumen  das Vielfache des Ball-Volumens mit einer Durchmesserlinie von 250 Zentimetern entspricht. Der exakte Seitenlänge für dieses Kubieren des Ba...
#
# --- Page 16 ---
# Das Entwurf der Giza-Pyramiden 16
# Wenn, wie der aktive Schriftsteller glaubt, die Existenz des Standortsplanes mit dem
# funerärigen Theorie nicht vereinbar ist, dann liegt es nicht an den fachlichen Beweisen für die Dimensionenrelationen, die fehlerhaft sind. Denn dies ist das Grundfest der Giza-P...
#
# Performance: {'elapsed_time_seconds': 124.90685057640076, 'total_tokens': 21495, 'tokens_per_second': 172.08823936243857}

# %%
# Replace with your own file path
summarize_file_path = "Files/The_Plan_of_the_Giza_Pyramids.pdf"
summary_ratio = 0.3  # 30% of original length


result = analyzer.summarize_document(summarize_file_path, summary_ratio)
print("\nSummary:")
print(result["summary"])
print("\nROUGE Scores:")
print(json.dumps(result["rouge_scores"], indent=2))
print("\nPerformance:", result["performance"])
# Out:
# 2025-04-13 17:23:35,334 - INFO - HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# Summary:
# The Giza site plan is a complex and intriguing subject that has been the focus of much scholarly debate over the years. Here are some key points to consider:
#
# 1. **Dimensional Relationships**: The layout of the pyramids and temples at Giza appears to be based on precise mathematical relationships, particularly involving prime numbers like 250 cubits.
#
# 2. **Historical Context**: Theories suggest that these structures were built as part of a grand initiation ceremony for priest-neophytes into ancient Egyptian wisdom, possibly dating back thousands of years before the Fourth Dynasty.
#
# 3. **Archaeological Evidence**: While some evidence suggests the pyramids may predate the Fourth Dynasty, others argue against this based on historical records and stone deliveries to the site.
#
# 4. **The Great Sphinx**: The presence of the Great Sphinx at Giza is significant as it appears to be integrated with the layout, possibly serving as a guardian of the mystery surrounding its origins.
#
# 5. **Historical Figures**: Khufu (Khafre) is mentioned in historical records but was likely not the original builder due to the need for stone contributions from the population. The Great Pyramid may have been built by someone else or under different circumstances.
#
# 6. **Theories and Claims**: There are various theories about the purpose of these structures, including their role as tombs, temples, or possibly even a grand initiation ceremony. Some claim they were constructed to initiate priest-neophytes into ancient Egyptian wisdom.
#
# 7. **Modern Relevance**: The Giza site plan continues to be studied for its potential connection to early Egyptian civilization and the origins of modern Egyptology.
#
# In summary, while there is substantial evidence supporting the historical existence of these structures as tombs or temples, their precise purpose remains a matter of debate among scholars. The mathematical relationships and integration with other ancient monuments suggest they may have played an important role in ancient Egyptian culture and religion.
#
# ROUGE Scores:
# {
#   "rouge-1": {
#     "r": 0.06729634002361275,
#     "p": 0.6031746031746031,
#     "f": 0.12108337578300862
#   },
#   "rouge-2": {
#     "r": 0.013820566877488873,
#     "p": 0.20921985815602837,
#     "f": 0.02592836622928576
#   },
#   "rouge-l": {
#     "r": 0.06316410861865407,
#     "p": 0.5661375661375662,
#     "f": 0.11364843154509041
#   }
# }
#
# Performance: {'elapsed_time_seconds': 4.44576358795166, 'total_tokens': 10008, 'tokens_per_second': 2251.1318476588367}

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ensure plots render in Jupyter Notebook
# %matplotlib inline

# Check if performance_metrics exists and has data
if hasattr(analyzer, "performance_metrics") and analyzer.performance_metrics:
    print("\nPerformance Metrics:")
    try:
        metrics_df = pd.DataFrame(analyzer.performance_metrics)
        display(metrics_df)
        
        # Plot tokens per second over time if available
        if "tokens_per_second" in metrics_df.columns:
            plt.figure(figsize=(10, 6))
            plt.plot(metrics_df["tokens_per_second"], marker='o', linestyle='-', color='b')
            plt.title("Tokens Per Second Over Operations")
            plt.xlabel("Operation Index")
            plt.ylabel("Tokens/Second")
            plt.grid(True)
            plt.show()
        else:
            print("No 'tokens_per_second' data available for plotting.")
    except Exception as e:
        print(f"Error displaying metrics: {str(e)}")
else:
    print("\nNo performance metrics available. Process some documents or perform operations to generate metrics.")
# Out:
# Performance Metrics:
#             operation                                file_path  \
# 0    process_document  Files/The_Plan_of_the_Giza_Pyramids.pdf
# 1  translate_document  Files/The_Plan_of_the_Giza_Pyramids.pdf
#
#    elapsed_time_seconds  total_tokens  tokens_per_second
# 0              5.790467         11439        1975.488325
# 1            124.906851         21495         172.088239
